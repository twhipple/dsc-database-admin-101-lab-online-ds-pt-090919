# %% [markdown]
# # Database Admin 101 - Lab
#
# ## Introduction
#
# In this lab, you'll go through the process of designing and creating a database. From there, you'll begin to populate this table with mock data provided to you.
#
# ## Objectives
#
# You will be able to:
#
# * Use knowledge of the structure of databases to create a database and populate it

# %% [markdown]
# ## The Scenario
#
# You are looking to design a database for a school that will house various information from student grades to contact information, class roster lists and attendance. First, think of how you would design such a database. What tables would you include? What columns would each table have? What would be the primary means to join said tables?

# %% [markdown]
# ## Creating the Database
#
# Now that you've put a little thought into how you might design your database, it's time to go ahead and create it! Start by import the necessary packages. Then, create a database called **school.sqlite**.

# %%
#Your code here; import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sqlite3

# %%
#Your code here; create the database school.sqlite
 
conn = sqlite3.connect('school.sqlite')
cur = conn.cursor()

# %%
ls
# Out:
# CONTRIBUTING.md        contact_list.pickle    school.sqlite-journal
# LICENSE.md             index.ipynb
# README.md              school.sqlite

# %%
cur.fetchall()
# Out:
# []

# %% [markdown]
# ## Create a Table for Contact Information
#
# Create a table called contactInfo to house contact information for both students and staff. Be sure to include columns for first name, last name, role (student/staff), telephone number, street, city, state, and zipcode. Be sure to also create a primary key for the table.

# %%
#Your code here
#Creating the tables
cur = conn.cursor()
cur.execute("""CREATE TABLE contactInfo (
                                        userId INTEGER PRIMARY KEY,
                                        firstName TEXT,
                                        lastName TEXT,
                                        role TEXT,
                                        telephone INTEGER,
                                        street TEXT,
                                        city TEXT,
                                        state TEXT,
                                        zipcode TEXT
                                        );
            """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-26-32f3aaed92b0> in <module>()
#      13                                         zipcode TEXT
#      14                                         );
# ---> 15             """)
#
# OperationalError: table contactInfo already exists

# %%
cur.execute("""SELECT * FROM contactInfo LIMIT 5;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#    userId    firstName  lastName     role   telephone  \
# 0       1    Christine    Holden    staff  2035687697
# 1       2  Christopher    Warren  student  2175150957
# 2       3        Linda  Jacobson    staff  4049446441
# 3       4       Andrew     Stepp  student  7866419252
# 4       7         Mary    Raines  student  9075772295
#
#                       street       city state zipcode
# 0         1672 Whitman Court   Stamford    CT   06995
# 1  1935 University Hill Road  Champaign    IL   61938
# 2        479 Musgrave Street    Atlanta    GA   30303
# 3  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 4      3975 Jerry Toth Drive  Ninilchik    AK   99639

# %% [markdown]
# ## Populate the Table
#
# Below, code is provided for you in order to load a list of dictionaries. Briefly examine the list. Each dictionary in the list will serve as an entry for your contact info table. Once you've briefly investigated the structure of this data, write a for loop to iterate through the list and create an entry in your table for each person's contact info.

# %%
# Code to load the list of dictionaries; just run this cell
import pickle

with open('contact_list.pickle', 'rb') as f:
    contacts = pickle.load(f)

# %%
# Their code to iterate over the contact list and populate the contactInfo table here
for contact in contacts:
    firstName = contact['firstName']
    lastName = contact['lastName']
    role = contact['role']
    telephone  = contact['telephone ']
    street = contact['street']
    city = contact['city']
    state = contact['state']
    zipcode  = contact['zipcode ']
    cur.execute("""INSERT INTO contactInfo (firstName, lastName, role, telephone, street, city, state, zipcode) 
                  VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');
                """.format(firstName, lastName, role, telephone, street, city, state, zipcode) )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-30-89411e08ebba> in <module>()
#      11     cur.execute("""INSERT INTO contactInfo (firstName, lastName, role, telephone, street, city, state, zipcode)
#      12                   VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');
# ---> 13                 """.format(firstName, lastName, role, telephone, street, city, state, zipcode) )
#
# OperationalError: database is locked

# %% [markdown]
# **Query the Table to Ensure it is populated**

# %%
# Your code here 
cur.execute("""SELECT * FROM contactInfo;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#     userId    firstName  lastName     role   telephone  \
# 0        1    Christine    Holden    staff  2035687697
# 1        2  Christopher    Warren  student  2175150957
# 2        3        Linda  Jacobson    staff  4049446441
# 3        4       Andrew     Stepp  student  7866419252
# 4        7         Mary    Raines  student  9075772295
# 5        8           Ed     Lyman  student  5179695576
# 6        9    Christine    Holden    staff  2035687697
# 7       10  Christopher    Warren  student  2175150957
# 8       11        Linda  Jacobson    staff  4049446441
# 9       12       Andrew     Stepp  student  7866419252
# 10      13         Jane     Evans  student  3259909290
# 11      14         Jane     Evans  student  3259909290
# 12      15         Mary    Raines  student  9075772295
# 13      16           Ed     Lyman  student  5179695576
#
#                        street       city state zipcode
# 0          1672 Whitman Court   Stamford    CT   06995
# 1   1935 University Hill Road  Champaign    IL   61938
# 2         479 Musgrave Street    Atlanta    GA   30303
# 3   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 4       3975 Jerry Toth Drive  Ninilchik    AK   99639
# 5         2910 Simpson Avenue       York    PA   17403
# 6          1672 Whitman Court   Stamford    CT   06995
# 7   1935 University Hill Road  Champaign    IL   61938
# 8         479 Musgrave Street    Atlanta    GA   30303
# 9   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 10        1461 Briarhill Lane    Abilene    TX   79602
# 11        1461 Briarhill Lane    Abilene    TX   79602
# 12      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 13              3478 Be Sreet    Lansing    MI   48933

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Persist your changes by committing them to the database.

# %%
#Your code here
conn.commit()

# %% [markdown]
# ## Create a Table for Student Grades
#
# Create a new table in the database called "grades". In the table, include the following fields: userId, courseId, grade.
#
# ** This problem is a bit more tricky and will require a dual key. (A nuance you have yet to see.)
# Here's how to do that:
#
# ```SQL
# CREATE TABLE table_name(
#    column_1 INTEGER NOT NULL,
#    column_2 INTEGER NOT NULL,
#    ...
#    PRIMARY KEY(column_1,column_2,...)
# );
# ```

# %%
#Your code here; create the grades table.
cur.execute("""CREATE TABLE grades (
                                    userId INTEGER NOT NULL,
                                    courseId INTEGER NOT NULL,
                                    grade INTEGER,
                                    PRIMARY KEY(userId, courseId)
                                    );
            """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-14-3c4e55f29688> in <module>()
#       6                                     PRIMARY KEY(userId, courseId)
#       7                                     );
# ----> 8             """)
#
# OperationalError: table grades already exists

# %%
cur.execute('''INSERT INTO contactInfo (firstName, lastName, role, telephone, street, city, state, zipcode) 
                VALUES ('Jane', 'Evans', 'student', 259909290, '1461 Briarhill Lane', 'Abilene', 'TX', 79602);
            ''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-36-373b3c830db2> in <module>()
#       1 cur.execute('''INSERT INTO contactInfo (firstName, lastName, role, telephone, street, city, state, zipcode)
#       2                 VALUES ('Jane', 'Evans', 'student', 259909290, '1461 Briarhill Lane', 'Abilene', 'TX', 79602);
# ----> 3             ''')
#
# OperationalError: database is locked

# %% [markdown]
# ## Remove Duplicate Entries
#
# An analyst just realized that there is a duplicate entry in the contactInfo table! Find and remove it.

# %%
#Your code here; find the duplicate entry
cur.execute("""SELECT firstName, lastName, telephone, COUNT(*) 
               FROM contactInfo
               GROUP BY 1,2,3
               HAVING COUNT(*) > 1;""").fetchall()
# Out:
# [('Andrew', 'Stepp', 7866419252, 2),
#  ('Christine', 'Holden', 2035687697, 2),
#  ('Christopher', 'Warren', 2175150957, 2),
#  ('Ed', 'Lyman', 5179695576, 2),
#  ('Jane', 'Evans', 3259909290, 2),
#  ('Linda', 'Jacobson', 4049446441, 2),
#  ('Mary', 'Raines', 9075772295, 2)]

# %%
#Your code here; delete the duplicate entry
cur.execute('''DELETE FROM contactInfo WHERE id = 11;''')

# %%
#Your code here; check that the duplicate entry was removed.
cur.execute("""SELECT * FROM contactInfo;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#     userId    firstName  lastName     role   telephone  \
# 0        1    Christine    Holden    staff  2035687697
# 1        2  Christopher    Warren  student  2175150957
# 2        3        Linda  Jacobson    staff  4049446441
# 3        4       Andrew     Stepp  student  7866419252
# 4        7         Mary    Raines  student  9075772295
# 5        8           Ed     Lyman  student  5179695576
# 6        9    Christine    Holden    staff  2035687697
# 7       10  Christopher    Warren  student  2175150957
# 8       11        Linda  Jacobson    staff  4049446441
# 9       12       Andrew     Stepp  student  7866419252
# 10      15         Mary    Raines  student  9075772295
# 11      16           Ed     Lyman  student  5179695576
#
#                        street       city state zipcode
# 0          1672 Whitman Court   Stamford    CT   06995
# 1   1935 University Hill Road  Champaign    IL   61938
# 2         479 Musgrave Street    Atlanta    GA   30303
# 3   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 4       3975 Jerry Toth Drive  Ninilchik    AK   99639
# 5         2910 Simpson Avenue       York    PA   17403
# 6          1672 Whitman Court   Stamford    CT   06995
# 7   1935 University Hill Road  Champaign    IL   61938
# 8         479 Musgrave Street    Atlanta    GA   30303
# 9   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 10      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 11              3478 Be Sreet    Lansing    MI   48933

# %% [markdown]
# ## Updating an Address
#
# Ed Lyman just moved to `2910 Simpson Avenue York, PA 17403`. Update his address accordingly.

# %%
#Your code here; update Ed's address
cur.execute('''UPDATE contactInfo
               SET street = "2910 Simpson Avenue",
                   city = 'York',
                   state = 'PA',
                   zipcode = '17403'
               WHERE firstName = "Ed" AND lastName = "Lyman";
            ''')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-37-398113108229> in <module>()
#       6                    zipcode = '17403'
#       7                WHERE firstName = "Ed" AND lastName = "Lyman";
# ----> 8             ''')
#
# OperationalError: database is locked

# %%
#Your code here; Query the database to ensure the change was made
cur.execute("""SELECT * FROM contactInfo;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#     userId    firstName  lastName     role   telephone  \
# 0        1    Christine    Holden    staff  2035687697
# 1        2  Christopher    Warren  student  2175150957
# 2        3        Linda  Jacobson    staff  4049446441
# 3        4       Andrew     Stepp  student  7866419252
# 4        7         Mary    Raines  student  9075772295
# 5        8           Ed     Lyman  student  5179695576
# 6        9    Christine    Holden    staff  2035687697
# 7       10  Christopher    Warren  student  2175150957
# 8       11        Linda  Jacobson    staff  4049446441
# 9       12       Andrew     Stepp  student  7866419252
# 10      13         Jane     Evans  student  3259909290
# 11      14         Jane     Evans  student  3259909290
# 12      15         Mary    Raines  student  9075772295
# 13      16           Ed     Lyman  student  5179695576
#
#                        street       city state zipcode
# 0          1672 Whitman Court   Stamford    CT   06995
# 1   1935 University Hill Road  Champaign    IL   61938
# 2         479 Musgrave Street    Atlanta    GA   30303
# 3   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 4       3975 Jerry Toth Drive  Ninilchik    AK   99639
# 5         2910 Simpson Avenue       York    PA   17403
# 6          1672 Whitman Court   Stamford    CT   06995
# 7   1935 University Hill Road  Champaign    IL   61938
# 8         479 Musgrave Street    Atlanta    GA   30303
# 9   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 10        1461 Briarhill Lane    Abilene    TX   79602
# 11        1461 Briarhill Lane    Abilene    TX   79602
# 12      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 13              3478 Be Sreet    Lansing    MI   48933

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Once again, persist your changes by committing them to the database.

# %%
#Your code here
conn.commit()

# %% [markdown]
# ## Summary
#
# While there's certainly more to do with setting up and managing this database, you got a taste for creating, populating, and maintaining databases! Feel free to continue fleshing out this exercise for more practice.
